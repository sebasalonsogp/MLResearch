# %%
import os
os.chdir('C:\\Users\\Sebas\\VSCProjects\\MLResearch')
print(os.getcwd())
# Out:
# C:\Users\Sebas\VSCProjects\MLResearch

# %%
from results import *
import matplotlib.pyplot as plt
import numpy as np
import json
from Scripts.functions import *

# %% [markdown]
# # Resnet18

# %% [markdown]
# ## Trained on MNIST, Evaluated on MNIST

# %%
execution_id = '2024-02-26-08-25-11'
model,dataset = 'resnet18', 'mnist'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/mnist/2024-02-26-08-25-11/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == 0:
            cosine_sim = data.get('cosine_similarity')
        if data.get('Execution_ID') == execution_id and data.get('L2_distance') and i == 0:
            l2= data.get('L2_distance')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %% [markdown]
# ## Trained on MNIST, Evaluated on FSHN

# %%
execution_id = '2024-02-26-08-25-11'
model,dataset = 'resnet18', 'mnist'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/mnist/2024-02-26-08-25-11/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('adj_cos_sim') and i == len(json_objects)-1:
            cosine_sim = data.get('adj_cos_sim')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# ## TODO average of mean, std, var across all classes

# %%
print_res(cosine_sim)
# Out:
# Class 9:
# Intra-class Similarity: Mean = 0.4060684044054445, Std = 0.37150298250015745, Var = 0.1380144660065123
# Inter-class similarity: Mean = -0.030529639901786757, Std = 0.4975165159775355, Var = 0.24752268367042535
#
# Class 0:
# Intra-class Similarity: Mean = 0.2696424608333187, Std = 0.6494670350377112, Var = 0.4218074296006756
# Inter-class similarity: Mean = -0.0038824180158752004, Std = 0.6455690317545215, Var = 0.4167593747604705
#
# Class 3:
# Intra-class Similarity: Mean = 0.18385470687498984, Std = 0.541683994518776, Var = 0.2934215499178174
# Inter-class similarity: Mean = -0.023622741611986145, Std = 0.5773937508813005, Var = 0.3333835435567773
#
# Class 2:
# Intra-class Similarity: Mean = 0.3488705969334055, Std = 0.6353684020046249, Var = 0.40369300626591054
# Inter-class similarity: Mean = -0.01276580331718071, Std = 0.6578816709678523, Var = 0.4328082929954535
#
# Class 7:
# ...

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('adj_cos_sim') and i == len(json_objects)-2:
            cosine_sim = data.get('adj_cos_sim')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %% [markdown]
# ## TODO plot variable

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# ## Trained on FSHN, Evaluated on FSHN

# %%
execution_id = '2024-02-26-08-33-57'
model,dataset = 'resnet18', 'fashion_mnist'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/fashion_mnist/2024-02-26-08-33-57/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == 0:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# ## Trained on FSHN, Evaluated on MNIST

# %%
execution_id = '2024-02-26-08-33-57'
model,dataset = 'resnet18', 'fashion_mnist'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/fashion_mnist/2024-02-26-08-33-57/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('adj_cos_sim') and i == len(json_objects)-1:
            cosine_sim = data.get('adj_cos_sim')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
plot_hist(cosine_sim)

# %%
aggregated_hist(cosine_sim)
print_res(cosine_sim)
# Out:
# Class 5:
# Intra-class Similarity: Mean = 0.1704936973622705, Std = 0.3104622744789402, Var = 0.09638682387463682
# Inter-class similarity: Mean = -0.002955432237678381, Std = 0.31043746008774864, Var = 0.09637141662573252
#
# Class 0:
# Intra-class Similarity: Mean = 0.24345498929682133, Std = 0.3384246044220922, Var = 0.11453121287824959
# Inter-class similarity: Mean = -0.010213801126040959, Std = 0.3308443800703826, Var = 0.10945800382415576
#
# Class 4:
# Intra-class Similarity: Mean = 0.20636063286584788, Std = 0.2875631782210657, Var = 0.0826925814686004
# Inter-class similarity: Mean = 0.008097698220549288, Std = 0.2829766762190999, Var = 0.08007579928400928
#
# Class 1:
# Intra-class Similarity: Mean = 0.6496823031611372, Std = 0.22111983619064948, Var = 0.04889398195697966
# Inter-class similarity: Mean = -0.06668558494935727, Std = 0.37788135308187143, Var = 0.14279431700698597
#
# Class 9:
# ...

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == len(json_objects)-1:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %%
print_res(cosine_sim)
# Out:
# Class 9:
# Intra-class Similarity: Mean = 0.4060684044054445, Std = 0.37150298250015745, Var = 0.1380144660065123
# Inter-class similarity: Mean = -0.030529639901786757, Std = 0.4975165159775355, Var = 0.24752268367042535
#
# Class 0:
# Intra-class Similarity: Mean = 0.2696424608333187, Std = 0.6494670350377112, Var = 0.4218074296006756
# Inter-class similarity: Mean = -0.0038824180158752004, Std = 0.6455690317545215, Var = 0.4167593747604705
#
# Class 3:
# Intra-class Similarity: Mean = 0.18385470687498984, Std = 0.541683994518776, Var = 0.2934215499178174
# Inter-class similarity: Mean = -0.023622741611986145, Std = 0.5773937508813005, Var = 0.3333835435567773
#
# Class 2:
# Intra-class Similarity: Mean = 0.3488705969334055, Std = 0.6353684020046249, Var = 0.40369300626591054
# Inter-class similarity: Mean = -0.01276580331718071, Std = 0.6578816709678523, Var = 0.4328082929954535
#
# Class 7:
# ...

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == len(json_objects)-1:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %% [markdown]
# ## Trained on CIFAR10, Evaluated on CIFAR10

# %%
execution_id = '2024-02-26-10-35-43'
model,dataset = 'resnet18', 'cifar10'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/cifar10/2024-02-26-10-35-43/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == 0:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# ## Trained on CIFAR10, Evaluated on CIFAR100

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == len(json_objects)-1:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# ## Trained on CIFAR100, Evaluated on CIFAR100

# %%
execution_id = '2024-02-26-09-03-16'
model,dataset = 'resnet18', 'cifar100'
model_path = f'./results/{model}/{dataset}/model_{model}_{dataset}_id_{execution_id}.pth'
result_path = f'./results/{model}/{dataset}/{execution_id}/results.json'
print(result_path)
# Out:
# ./results/resnet18/cifar100/2024-02-26-09-03-16/results.json

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == 0:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %% [markdown]
# ## Trained on CIFAR100, Evaluated on CIFAR10

# %%
with open(result_path, 'r') as f:
    content = f.read()

json_objects = content.split(',\n')

for i,obj in enumerate(json_objects):
    try:
        data = json.loads(obj)
        if data.get('Execution_ID') == execution_id and data.get('cosine_similarity') and i == len(json_objects)-1:
            cosine_sim = data.get('cosine_similarity')
    except json.JSONDecodeError:
        print("Error decoding json object. Skipping.")

# %%
aggregated_hist(cosine_sim)

# %% [markdown]
# # DenseNet
